# %% [markdown]
# Problem Statement:
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g., https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
#
# List down the features and their types (e.g., numeric, nominal) available in the dataset.
# Create a histogram for each feature in the dataset to illustrate the feature distributions.
# Create a box plot for each feature in the dataset.
# Compare distributions and identify outliers.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = datasets.load_iris()

# %%
df = pd.DataFrame(iris.data)

# %%
df.columns = iris.feature_names

# %%
df['class'] = iris.target

# %%
df['class'] = df['class'].map({0:iris.target_names[0],1:iris.target_names[1],2:iris.target_names[2]})

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          class
# 0       setosa
# ...

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     class
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   class              150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Feature Information:
#
# <br>sepal length in cm type float (numeric)
# <br>sepal width in cm type float (numeric)
# <br>petal length in cm type float (numeric)
# <br>petal width in cm type float (numeric)
# <br>class type object (nominal):
# <br>Iris Setosa
# <br>Iris Versicolour
# <br>Iris Virginica

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of sepal length")
sns.histplot(df['sepal length (cm)'],color='Blue')
# Out:
# <AxesSubplot:title={'center':'Distribution of sepal length'}, xlabel='sepal length (cm)', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of sepal width")
sns.histplot(df['sepal width (cm)'],color='Red')
# Out:
# <AxesSubplot:title={'center':'Distribution of sepal width'}, xlabel='sepal width (cm)', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of petal length")
sns.histplot(df['petal length (cm)'],color='Green')
# Out:
# <AxesSubplot:title={'center':'Distribution of petal length'}, xlabel='petal length (cm)', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
plt.title("Distribution of petal width")
sns.histplot(df['petal width (cm)'],color='Yellow')
# Out:
# <AxesSubplot:title={'center':'Distribution of petal width'}, xlabel='petal width (cm)', ylabel='Count'>

# %%
fig, axs = plt.subplots(2, 2, figsize=(12,12))
fig.suptitle('Distributions of features', fontsize=16)
axs[0][0].set_title('Distribution of sepal length')
sns.kdeplot(x='sepal length (cm)', data=df, ax=axs[0][0], hue='class')
axs[0][1].set_title('Distribution of sepal width')
sns.kdeplot(x='sepal width (cm)', data=df, ax=axs[0][1], hue='class')
axs[1][0].set_title('Distribution of petal length')
sns.kdeplot(x='petal length (cm)', data=df, ax=axs[1][0], hue='class')
axs[1][1].set_title('Distribution of petal width')
sns.kdeplot(x='petal width (cm)', data=df, ax=axs[1][1], hue='class')
# Out:
# <AxesSubplot:title={'center':'Distribution of petal width'}, xlabel='petal width (cm)', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
plt.title('Box plots of all features in the dataset.')
sns.boxplot(data=df, hue='class')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       1 plt.figure(figsize=(12,8))
#       2 plt.title('Box plots of all features in the dataset.')
# ----> 3 sns.boxplot(data=df, hue='class')
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
iris_long = df.melt(id_vars=['class'])
ax = sns.boxplot(data=iris_long, x="value", y="variable", orient="h", hue="class")
plt.figure(figsize=(12,8))
plt.show()
